# %%
## 1) The Dataset Downloaded
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
## 2) The Dataset loaded
df = pd.read_csv("C:\Test jupyter\House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area
# 0  6762810145  42491                   5                 2.50         3650  \
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views
# 0      9050               2.0                   0                4  \
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
df.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# ...

# %%
df.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
x= df.iloc [:,0:22]
y= df.iloc [:,-1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
import seaborn as sns

# %%
## 3a) Univariate Analysis - single value as parameter

# %%
sns.histplot(df.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.distplot(df.Price)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6992\824416946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df.Price,kde=False,bins=50)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13284\532859929.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price,kde=False,bins=50)
# <Axes: xlabel='Price'>

# %%
sns.jointplot(x = df['Price'], y = df['grade of the house'], kind = 'scatter')

# %%
sns.jointplot(x = df['Price'], y = df['grade of the house'], kind = 'hex')

# %%
## 3b) BiVariate Analysis - 2 value comparision.
sns.jointplot(x = df['Price'], y = df['grade of the house'], kind = 'reg')

# %%
sns.rugplot(x = df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.barplot(x = df['number of bedrooms'], y = df['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %%
sns.countplot(df['Price'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(x = df['number of bedrooms'], y = df['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %%
sns.violinplot(x = df['number of bedrooms'], y = df['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %%
sns.stripplot(y = df['Price'], x = df['Distance from the airport'])
# Out:
# <Axes: xlabel='Distance from the airport', ylabel='Price'>

# %%
df.corr()
# Out:
#                                              id      Date  number of bedrooms
# id                                     1.000000  0.045966           -0.329034  \
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
sns.lineplot(x = df['number of bedrooms'], y = df['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %%
sns.scatterplot(x = df['number of bedrooms'], y = df['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %%
sns.lineplot(x = df['number of bedrooms'], y = df['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %%
## 3c) MultiVariate Analysis - multiple values can be provided ##

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %%
## 4) Descriptive Statistics like scatterplot,Boxplot.
sns.boxplot(df.Price)
# Out:
# <Axes: >

# %%
sns.boxplot(df.Lattitude)
# Out:
# <Axes: >

# %%
sns.boxplot(df.Longitude)
# Out:
# <Axes: >

# %%
## 5) Handle Missing Values:-
df.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
## This shows that there are no missing values in the given Dataset
